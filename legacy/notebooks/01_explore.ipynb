# %% [markdown]
# # Dataset Exploration (Phase 1)
#
# TODO: for each dataset (Kaggle SQLiV3, CSIC 2010, CICIDS2017, ATRDF 2023) print shape, columns, label distribution, sample rows, and class imbalance ratios.
